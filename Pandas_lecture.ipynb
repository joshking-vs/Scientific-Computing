# %%
import pandas as pd

# %%
dataX = pd.read_csv(r"c:\Users\ADMIN\Downloads\sample_data.csv.xls")

# %%
dataX
# Out:
#    temperature  humidity   category
# 0           22        55    Science
# 1           25        60       Math
# 2           27        65    Physics
# 3           30        70    Biology
# 4           35        75  Chemistry

# %%
datay = pd.read_csv(r"c:\Users\ADMIN\Downloads\Electric_Vehicle_Population_Data.csv")

# %%
datay
# Out:
#         VIN (1-10)     County         City State  Postal Code  Model Year  \
# 0       2T3YL4DV0E       King     Bellevue    WA      98005.0        2014
# 1       5YJ3E1EB6K       King      Bothell    WA      98011.0        2019
# 2       5UX43EU02S   Thurston      Olympia    WA      98502.0        2025
# 3       JTMAB3FV5R   Thurston      Olympia    WA      98513.0        2024
# 4       5YJYGDEE8M     Yakima        Selah    WA      98942.0        2021
# ...            ...        ...          ...   ...          ...         ...
# 232225  5YJ3E1EA3K       King       Renton    WA      98058.0        2019
# 232226  1GKB0RDC1R  Snohomish    Snohomish    WA      98290.0        2024
# 232227  7SAYGDED3R       King      Redmond    WA      98033.0        2024
# 232228  JTMEB3FV5P     Chelan  Leavenworth    WA      98826.0        2023
# 232229  5YJYGDEE3M     Kitsap    Bremerton    WA      98312.0        2021
#
#           Make          Model                   Electric Vehicle Type  \
# ...

# %%
dataz = pd.read_csv(r"c:\Users\ADMIN\Downloads\Crime_Data_from_2020_to_Present.csv")
dataz
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1        200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2        200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3        200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4        200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630
# ...            ...                     ...                     ...       ...
# 1005099  250304184  02/18/2025 12:00:00 AM  02/14/2025 12:00:00 AM      1200
# 1005100  252104053  01/19/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1530
# 1005101  250304214  02/23/2025 12:00:00 AM  02/21/2025 12:00:00 AM      1530
# 1005102  250304203  02/20/2025 12:00:00 AM  02/13/2025 12:00:00 AM      2100
# 1005103  250504051  01/14/2025 12:00:00 AM  01/14/2025 12:00:00 AM      1250
#
# ...

# %%
dataz.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.005104e+06  1.005104e+06  1.005104e+06  1.005104e+06  1.005104e+06
# mean   2.202253e+08  1.339912e+03  1.069102e+01  1.115561e+03  1.400287e+00
# std    1.319645e+07  6.510650e+02  6.110349e+00  6.111694e+02  4.899567e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209160e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311104e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.005104e+06  1.005104e+06  1.005088e+06   327244.000000  1.005093e+06
# mean   5.001423e+02  2.891422e+01  3.056138e+02      363.949258  4.999029e+02
# ...

# %%
dataX.columns
# Out:
# Index(['temperature', 'humidity', 'category'], dtype='object')

# %%
dataX.describe()
# Out:
#        temperature   humidity
# count     5.000000   5.000000
# mean     27.800000  65.000000
# std       4.969909   7.905694
# min      22.000000  55.000000
# 25%      25.000000  60.000000
# 50%      27.000000  65.000000
# 75%      30.000000  70.000000
# max      35.000000  75.000000

# %%
dataX.describe(include='all')
# Out:
#         temperature   humidity category
# count      5.000000   5.000000        5
# unique          NaN        NaN        5
# top             NaN        NaN  Science
# freq            NaN        NaN        1
# mean      27.800000  65.000000      NaN
# std        4.969909   7.905694      NaN
# min       22.000000  55.000000      NaN
# 25%       25.000000  60.000000      NaN
# 50%       27.000000  65.000000      NaN
# 75%       30.000000  70.000000      NaN
# max       35.000000  75.000000      NaN

# %%
dataX.head(2)
# Out:
#    temperature  humidity category
# 0           22        55  Science
# 1           25        60     Math

# %%
dataX.tail(2)
# Out:
#    temperature  humidity   category
# 3           30        70    Biology
# 4           35        75  Chemistry

# %%
dataX.sample(2)
# Out:
#    temperature  humidity   category
# 2           27        65    Physics
# 4           35        75  Chemistry

# %%
dataX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  5 non-null      int64
#  1   humidity     5 non-null      int64
#  2   category     5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
type(dataX["temperature"])
# Out:
# pandas.core.series.Series

# %%
dataX[["temperature","humidity"]]
# Out:
#    temperature  humidity
# 0           22        55
# 1           25        60
# 2           27        65
# 3           30        70
# 4           35        75

# %%
high_temp = dataX[dataX['temperature']>30]

# %%
high_temp
# Out:
#    temperature  humidity   category
# 4           35        75  Chemistry

# %%
dataX['temperature'].mean()
# Out:
# np.float64(27.8)

# %%
dataX['temperature'].median()
# Out:
# np.float64(27.0)

# %%
dataX['temperature'].mode()
# Out:
# 0    22
# 1    25
# 2    27
# 3    30
# 4    35
# Name: temperature, dtype: int64

# %%
dataX['temperature'].std()
# Out:
# np.float64(4.969909455915671)

# %%
dataNum = dataX.drop(['category'],axis=1)
dataNum
# Out:
#    temperature  humidity
# 0           22        55
# 1           25        60
# 2           27        65
# 3           30        70
# 4           35        75

# %%
dataNum.corr()
# Out:
#              temperature  humidity
# temperature     1.000000  0.986241
# humidity        0.986241  1.000000

# %% [markdown]
# #DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %%
dataX["temperature"].hist(bins=5)
# Out:
# <Axes: >

# %%
#cleaning and preprocessing scientific data

# %%
#filling missing values

# %%
dataNum.fillna(dataNum.mean(),inplace=True)

# %% [markdown]
# #Handling outliers

# %% [markdown]
# #identifying and removing outliers using the interquartile range

# %%
dataX
# Out:
#    temperature  humidity   category
# 0           22        55    Science
# 1           25        60       Math
# 2           27        65    Physics
# 3           30        70    Biology
# 4           35        75  Chemistry

# %%
Q1 = dataX['temperature'].quantile(0.25)

# %%
Q1
# Out:
# np.float64(25.0)

# %%
Q3 = dataX['temperature'].quantile(0.75)

# %%
IQR = Q3 - Q1 
IQR
# Out:
# np.float64(5.0)

# %% [markdown]
# #Normalizing and transforming data

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
df_scaled = scaler.fit_transform(dataX[['temperature','humidity']])
df_scaled
# Out:
# array([[-1.30477168, -1.41421356],
#        [-0.62988978, -0.70710678],
#        [-0.17996851,  0.        ],
#        [ 0.4949134 ,  0.70710678],
#        [ 1.61971657,  1.41421356]])

# %% [markdown]
# #job of the day- kaggle has a lot of data,,,load and inspect it, handle missing values and outliers(make sure data downloaded has missing values, Compue key statistics(mode,median,mean..etc), Generate visualization(histogram,scatterplot,correlation heatmap))
